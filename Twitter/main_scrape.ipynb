# %%
"""Imports"""
import selenium
from datetime import datetime
from time import sleep as wait
from selenium import webdriver
from selenium.webdriver import Chrome
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException

#####################################################################################

""" URL """
username = "NEARProtocol"
#url = f'https://twitter.com/{username}'
url = "https://twitter.com/search?q=on%20NEAR%20blockchain&src=typed_query&f=live"

""" FILTERS """
stringys = ["ido", "upcoming", "fundraising", "launch", "NEP", "hiring", "seed", "private"]
before_date = datetime(2022, 6, 30)

#####################################################################################

#Creating an instance of a webdriver
PATH = "C:\Program Files (x86)\chromedriver.exe"
driver = webdriver.Chrome(PATH)

#GENERATE THE REQUEST !
driver.get(url)

#wait till load
wait(20)
print("Page ready !")

#Create tweet ID's for already scraped tweets
tweet_ids = set()
tweet_data = []

#Check if I'm at the end of the page
last_pos = driver.execute_script("return document.body.scrollHeight")
#print(last_pos)

#Set scrolilng
scrolling = True
in_range = True

#Looping through tweets
while scrolling:
    #Define the tweet segment
    cards = driver.find_elements(By.CSS_SELECTOR, "article")
    
    for card in cards: 
        
        """ Function """
        try:
            #Elements
            #GET FULL XPATH AND FOLLOW THROUGH AFTER TAG "ARTICLE" 
            text = card.find_element(By.XPATH, './div/div/div/div[2]/div[2]/div[2]/div[1]').text
            responding = card.find_element(By.XPATH, './div/div/div/div[2]/div[2]/div[2]/div[2]').text
            handle = card.find_element(By.XPATH, './/*[contains(text(),"@")]').text
            #replies = card.find_element_by_xpath('.//div[@data-testid="reply"]').text
            #retweets = card.find_element_by_xpath('.//div[@data-testid="retweet"]').text
            #likes = card.find_element_by_xpath('.//div[@data-testid="like"]').text
            #pinned = card.find_element_by_xpath('./div/div/div/div[1]/div/div/div/div/div[2]/div/div/div').text
            full_txt = text+responding
            
            #Sponsored tweets have no date
            date = card.find_element(By.XPATH, './/time').get_attribute('datetime')

            """STR date into python datetime object"""
            #date = date.rstrip(".000Z")
            date = date[:-5]
            date = date.replace("T", " ")
            date_obj = datetime.strptime(date, '%Y-%m-%d %H:%M:%S')
            #print(date_obj)
            
        #NoSuchElement error handling
        except NoSuchElementException:
            pass
        #StaleElementReferenceException error handling
        except StaleElementReferenceException:
            pass
        
        if any(s in text.lower() for s in stringys):
        
            if date_obj > before_date:
                #Create a tuple for the tweet
                tweet = (handle, date, full_txt)

                #Create the tweet DF
                tweet_id = ''.join(tweet)

                #Add only tweets not already seen
                if tweet_id not in tweet_ids:
                    #Add id & data
                    tweet_ids.add(tweet_id)
                    tweet_data.append(tweet)
                    print(tweet)
                    print("---------0---------")

        if date_obj < before_date:
            scrolling = False
            in_range = False
            print("tweet out of range")
            break

            
    scrolling_attempt = 0
    
    while in_range == True:
        #Finally adding pagination
        driver.execute_script("window.scrollBy(0,500)")
        wait(1)

        #Current position and comparison to check if I'm at the bottom
        curr_pos = driver.execute_script("return document.body.scrollHeight")
        #print("current position:")
        #print(curr_pos)
        
        if last_pos == curr_pos: 
            #If I scrolled and ended up in the same place //nothing loaded//
            scrolling_attempt +=1
            
            #End of scroll region
            if scrolling_attempt >= 5: 
                scrolling = False
                break
            else:
                print(f'{scrolling_attempt}^st Attempt to scroll. Break in 5th.')
                wait(2)
        else:
            last_pos = curr_pos
            break
    else:
        break
                
"""Results"""
print("---------------------------------------------------")
print(f'Amount of tweets collected: {len(tweet_data)}')
print("---------------------------------------------------")

driver.quit()
# Out:
# C:\Users\Usuario\AppData\Local\Temp/ipykernel_17252/637932234.py:27: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(PATH)
# Page ready !
# ('@Tee_Monera', '2022-07-12 14:40:17', 'Other nfts and nametags. \n• Holders will be given an exclusive key to the first mobile tracker app on the near blockchain, which is the freedom wall art tracker. \n•That gives update on upcoming and existing projects on #nearNFTs\n• Evolution tool \n• And other benefits!!1\n1\n5')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 3^st Attempt to scroll. Break in 5th.
# 4^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@Steps2Rank1', '2022-07-09 00:46:05', 'GAMBING Reaches alpha testing, launching in the near future on \n@HPB_Global\n $hpb blockchain!! \n\nCheck out my short video! \n\n\n\nhttps://tiktok.com/t/ZTRFwYetj/?k=1…\n\n#Blockchain #CryptoNews #gambling #gaming #Bitcoin #ETH #altcoin')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 3^st Attempt to scroll. Break in 5th.
# 4^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@Grokerino', '2022-07-06 22:25:50', 'I have been thinking about a decentralized self sovereign ID \n@AtalaPrismio\n on a Blockchain. The biggest problem is that it will be near impossible to maintain and restore private keys in the face of whatever happens in life. \n@UtahPolitician\n @akrishnan232')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 3^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@Oscom2', '2022-07-06 13:37:54', 'Very cool to see \n@PlayBlankos\n launch on the epic game store in the near future. \n\nHas been the most fun *blockchain* game i played until now. \nStill a lot of room for improvement ofc but since it has a very healthy model in regards to their NFTs, curious to see how it goes3')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@MoralGuys', '2022-07-06 00:00:01', "Bear market? Winter? You're really missing out. Join us, join the party. Giveaways near daily. Alpha on launches. Multiple airdrops incoming. And MoralChain, our very own blockchain- Wallet, dApps, the works. \n\nhttps://discord.gg/PshU8zqn\n\n#NFTs #cryptocurrency #NFTCommunitydiscord.com\nDiscord - A New Way to Chat with Friends & Communities\nDiscord is the easiest way to communicate over voice, video, and text. Chat, hang out, and stay close with your friends and communities.")
# ---------0---------
# ('@cryptobri_', '2022-07-05 23:23:09', 'NEWS\n\nNearX Mainnet is launching on July 7th\n\nYou can register  to be a part of the Alpha group & experience NearX before everyone else!\n\nhttps://forms.gle/pfzyQvZxwLMnWBMm9…\n\n$2000 USDC #Giveaway\n@stader__near\n #blockchain #cryptonews #nearx #staking #defi #crypto #doge #DYOR #ad')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@cryptobri_', '2022-07-05 23:23:09', 'NEWS\n\nNearX Mainnet is launching on July 7th\n\nYou can register  to be a part of the Alpha group & experience NearX before everyone else!\n\nhttps://forms.gle/pfzyQvZxwLMnWBMm9…\n\n$2000 USDC #Giveaway\n@stader__near\n #blockchain #cryptonews #nearx #staking #defi #crypto #doge #DYOR #ad10,5 mil reproducciones\n0:03 / 1:00')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 3^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 3^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@wasimsupaul', '2022-07-02 07:06:56', '1. What is NEARStarter?\n\nNEARStarter is a next-generation launchpad and tokenized incubator to support the world’s best DeFi and Web3 entrepreneurs to hyper-scale and launch their projects on the NEAR blockchain. It will help the Near ecosystem to reach its full potential.1')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
# ('@FritzWG', '2022-06-30 16:08:52', '4 many reasons, \n@NEAR_Blockchain\n is amazingly beneficial for the growth of NFT and web3 projects\n\nThe $Near Community shows positive values like Openness, Inclusion, Integrity, and Accountability \n\nTherefore, \n@BEExperience_\n is launching their NFT collection on \n@NEAR_Blockchain3')
# ---------0---------
# ('@FritzWG', '2022-06-30 16:00:39', 'As is on their profile description\n \n@BEExperience_\n the HUB of education and recruitment within web3 for \n@NEAR_Blockchain\n \nProviding services to hiring entities as well as individuals seeking employment\n \nAllowing NEAReans with web3 exp to grow even further as professionals')
# ---------0---------
# 1^st Attempt to scroll. Break in 5th.
# 2^st Attempt to scroll. Break in 5th.
# 1^st Attempt to scroll. Break in 5th.
